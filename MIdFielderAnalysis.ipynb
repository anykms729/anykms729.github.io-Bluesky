# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Mount your Google Drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/MCI Women_s Files/Jsonl_distance_with_ball_and_pos.csv")
df.head()
# Out:
#    period  frameIdx  gameClock      wallClock  \
# 0       1         0       0.00  1676118667880
# 1       1         1       0.04  1676118667920
# 2       1         2       0.08  1676118667960
# 3       1         3       0.12  1676118668000
# 4       1         4       0.16  1676118668040
#
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00                192194
# 1  [-11.08, 1.57, 0.0]                 0.00                192194
# 2  [-11.07, 1.59, 0.0]                 0.53                192194
# 3  [-11.07, 1.61, 0.0]                 0.60                192194
# 4  [-11.05, 1.63, 0.0]                 0.64                192194
#
#                  homePlayers_2_playerId  ...  homePlayers_7_position  \
# 0  08d71d20-85ad-4d98-8bc0-36b8e39e517a  ...                      DF
# 1  08d71d20-85ad-4d98-8bc0-36b8e39e517a  ...                      DF
# 2  08d71d20-85ad-4d98-8bc0-36b8e39e517a  ...                      DF
# 3  08d71d20-85ad-4d98-8bc0-36b8e39e517a  ...                      DF
# 4  08d71d20-85ad-4d98-8bc0-36b8e39e517a  ...                      DF
#
#   awayPlayers_7_position  homePlayers_8_position  awayPlayers_8_position  \
# 0                     FW                      DF                      MF
# 1                     FW                      DF                      MF
# 2                     FW                      DF                      MF
# 3                     FW                      DF                      MF
# 4                     FW                      DF                      MF
#
#   homePlayers_9_position  awayPlayers_9_position homePlayers_10_position  \
# 0                     DF                      GK                      FW
# 1                     DF                      GK                      FW
# 2                     DF                      GK                      FW
# 3                     DF                      GK                      FW
# 4                     DF                      GK                      FW
#
#    awayPlayers_10_position  homePlayers_11_position awayPlayers_11_position
# 0                       FW                       DF                      DF
# 1                       FW                       DF                      DF
# 2                       FW                       DF                      DF
# 3                       FW                       DF                      DF
# 4                       FW                       DF                      DF
#
# [5 rows x 162 columns]

# %%
home_cols = [c for c in df.columns if "home" in  c if "_1_" not in c]
home_cols

# %%
away_cols = [c for c in df.columns if "away" in c]
away_cols

# %%
hpos_cols = [c for c in home_cols if "position" in c]
hpos_cols
# Out:
# ['homePlayers_2_position',
#  'homePlayers_3_position',
#  'homePlayers_4_position',
#  'homePlayers_5_position',
#  'homePlayers_6_position',
#  'homePlayers_7_position',
#  'homePlayers_8_position',
#  'homePlayers_9_position',
#  'homePlayers_10_position',
#  'homePlayers_11_position']

# %%
apos_cols = [c for c in away_cols if "position" in c]
apos_cols
# Out:
# ['awayPlayers_1_position',
#  'awayPlayers_2_position',
#  'awayPlayers_3_position',
#  'awayPlayers_4_position',
#  'awayPlayers_5_position',
#  'awayPlayers_6_position',
#  'awayPlayers_7_position',
#  'awayPlayers_8_position',
#  'awayPlayers_9_position',
#  'awayPlayers_10_position',
#  'awayPlayers_11_position']

# %% [markdown]
# ** **bold text**Jersey Number of Midfielders**

# %%
req_home_players_num = list()
for pc in hpos_cols:
  if df[pc].loc[0]=="MF":
    # print(pc)
    req_home_players_num.append(pc.split("_")[1])

req_home_players_num
# Out:
# ['3', '5']

# %%
req_away_players_num = list()
for pc in apos_cols:
  if df[pc].loc[0]=="MF":
    # print(pc)
    req_away_players_num.append(pc.split("_")[1])

req_away_players_num
# Out:
# ['1', '8']

# %% [markdown]
# **Required columns for dataframe**

# %%
req_home_players = list()
for c in home_cols:
  if c.split("_")[1] in req_home_players_num:
    req_home_players.append(c)
req_home_players
# Out:
# ['homePlayers_3_playerId',
#  'homePlayers_3_number',
#  'homePlayers_3_xyz',
#  'homePlayers_3_speed',
#  'homePlayers_3_optaId',
#  'homePlayers_5_playerId',
#  'homePlayers_5_number',
#  'homePlayers_5_xyz',
#  'homePlayers_5_speed',
#  'homePlayers_5_optaId',
#  'homePlayers_3_ballDistance',
#  'homePlayers_5_ballDistance',
#  'homePlayers_3_position',
#  'homePlayers_5_position']

# %%
req_away_players = list()
for c in away_cols:
  if c.split("_")[1] in req_away_players_num:
    req_away_players.append(c)
req_away_players
# Out:
# ['awayPlayers_1_playerId',
#  'awayPlayers_1_number',
#  'awayPlayers_1_xyz',
#  'awayPlayers_1_speed',
#  'awayPlayers_1_optaId',
#  'awayPlayers_8_playerId',
#  'awayPlayers_8_number',
#  'awayPlayers_8_xyz',
#  'awayPlayers_8_speed',
#  'awayPlayers_8_optaId',
#  'awayPlayers_1_ballDistance',
#  'awayPlayers_8_ballDistance',
#  'awayPlayers_1_position',
#  'awayPlayers_8_position']

# %% [markdown]
# **Total Required Columns**

# %%
hp1_cols = [c for c in list(df.columns) if "homePlayers_1_" in c]
req_cols = hp1_cols + req_home_players + req_away_players
req_cols.extend(["period","frameIdx","gameClock","wallClock"])
req_cols
# Out:
# ['homePlayers_1_playerId',
#  'homePlayers_1_number',
#  'homePlayers_1_xyz',
#  'homePlayers_1_speed',
#  'homePlayers_1_optaId',
#  'homePlayers_1_ballDistance',
#  'homePlayers_1_position',
#  'homePlayers_3_playerId',
#  'homePlayers_3_number',
#  'homePlayers_3_xyz',
#  'homePlayers_3_speed',
#  'homePlayers_3_optaId',
#  'homePlayers_5_playerId',
#  'homePlayers_5_number',
#  'homePlayers_5_xyz',
#  'homePlayers_5_speed',
#  'homePlayers_5_optaId',
#  'homePlayers_3_ballDistance',
#  'homePlayers_5_ballDistance',
#  'homePlayers_3_position',
#  'homePlayers_5_position',
#  'awayPlayers_1_playerId',
#  'awayPlayers_1_number',
#  'awayPlayers_1_xyz',
#  'awayPlayers_1_speed',
#  'awayPlayers_1_optaId',
#  'awayPlayers_8_playerId',
#  'awayPlayers_8_number',
#  'awayPlayers_8_xyz',
#  'awayPlayers_8_speed',
#  'awayPlayers_8_optaId',
#  'awayPlayers_1_ballDistance',
#  'awayPlayers_8_ballDistance',
#  'awayPlayers_1_position',
#  'awayPlayers_8_position',
#  'period',
#  'frameIdx',
#  'gameClock',
#  'wallClock']

# %%
df_hp1 = df[req_cols]
df_hp1.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00                192194
# 1  [-11.08, 1.57, 0.0]                 0.00                192194
# 2  [-11.07, 1.59, 0.0]                 0.53                192194
# 3  [-11.07, 1.61, 0.0]                 0.60                192194
# 4  [-11.05, 1.63, 0.0]                 0.64                192194
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
#
#     homePlayers_3_xyz  ...  awayPlayers_8_speed  awayPlayers_8_optaId  \
# 0  [-2.71, 8.54, 0.0]  ...                 0.00                 96380
# 1  [-2.71, 8.52, 0.0]  ...                 0.00                 96380
# 2   [-2.71, 8.5, 0.0]  ...                 0.53                 96380
# 3  [-2.72, 8.48, 0.0]  ...                 0.64                 96380
# 4  [-2.72, 8.46, 0.0]  ...                 0.69                 96380
#
#   awayPlayers_1_ballDistance  awayPlayers_8_ballDistance  \
# 0                  12.305385                   16.187517
# 1                  12.822613                   16.609226
# 2                  13.338504                   17.057421
# 3                  13.810362                   17.436012
# 4                  14.301094                   17.855800
#
#   awayPlayers_1_position  awayPlayers_8_position  period  frameIdx  gameClock  \
# 0                     MF                      MF       1         0       0.00
# 1                     MF                      MF       1         1       0.04
# 2                     MF                      MF       1         2       0.08
# 3                     MF                      MF       1         3       0.12
# 4                     MF                      MF       1         4       0.16
#
#        wallClock
# 0  1676118667880
# 1  1676118667920
# 2  1676118667960
# 3  1676118668000
# 4  1676118668040
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (151605, 162)

# %% [markdown]
# **Distance Function**

# %%
import ast
import numpy as np
def calculate_distance_from_Player(home_1_pos,other_pos):
  distance_list = []
  home_pos_list = [ast.literal_eval(s) for s in home_1_pos]
  away_pos_list = [ast.literal_eval(s) for s in other_pos]
  for pos in zip(home_pos_list, away_pos_list):
    distance = np.sqrt((pos[0][0] - pos[1][0])**2 + (pos[0][1] - pos[1][1])**2)
    distance_list.append(distance)
  return distance_list

# %%
other_player_cols = [c for c in list(df_hp1.columns) if "xyz" in  c if "homePlayers_1_xyz" not in c]
other_player_cols
# Out:
# ['homePlayers_3_xyz',
#  'homePlayers_5_xyz',
#  'awayPlayers_1_xyz',
#  'awayPlayers_8_xyz']

# %%
for col in other_player_cols:
  i = col.split("_")[1]
  if "home" in col:
    print("homePlayers_1_homePlayers_"+str(i)+"_Distance")
    df_hp1["homePlayers_1_homePlayers_"+str(i)+"_Distance"] = calculate_distance_from_Player(df_hp1["homePlayers_1_xyz"], df_hp1[col])
  else:
    print("homePlayers_1_awayPlayers_"+str(i)+"_Distance")
    df_hp1["homePlayers_1_awayPlayers_"+str(i)+"_Distance"] = calculate_distance_from_Player(df_hp1["homePlayers_1_xyz"], df_hp1[col])
# Out:
# homePlayers_1_homePlayers_3_Distance
# homePlayers_1_homePlayers_5_Distance
# homePlayers_1_awayPlayers_1_Distance
# homePlayers_1_awayPlayers_8_Distance

# %%
list(df_hp1.columns)
# Out:
# ['homePlayers_1_playerId',
#  'homePlayers_1_number',
#  'homePlayers_1_xyz',
#  'homePlayers_1_speed',
#  'homePlayers_1_optaId',
#  'homePlayers_1_ballDistance',
#  'homePlayers_1_position',
#  'homePlayers_3_playerId',
#  'homePlayers_3_number',
#  'homePlayers_3_xyz',
#  'homePlayers_3_speed',
#  'homePlayers_3_optaId',
#  'homePlayers_5_playerId',
#  'homePlayers_5_number',
#  'homePlayers_5_xyz',
#  'homePlayers_5_speed',
#  'homePlayers_5_optaId',
#  'homePlayers_3_ballDistance',
#  'homePlayers_5_ballDistance',
#  'homePlayers_3_position',
#  'homePlayers_5_position',
#  'awayPlayers_1_playerId',
#  'awayPlayers_1_number',
#  'awayPlayers_1_xyz',
#  'awayPlayers_1_speed',
#  'awayPlayers_1_optaId',
#  'awayPlayers_8_playerId',
#  'awayPlayers_8_number',
#  'awayPlayers_8_xyz',
#  'awayPlayers_8_speed',
#  'awayPlayers_8_optaId',
#  'awayPlayers_1_ballDistance',
#  'awayPlayers_8_ballDistance',
#  'awayPlayers_1_position',
#  'awayPlayers_8_position',
#  'period',
#  'frameIdx',
#  'gameClock',
#  'wallClock',
#  'homePlayers_1_homePlayers_3_Distance',
#  'homePlayers_1_homePlayers_5_Distance',
#  'homePlayers_1_awayPlayers_1_Distance',
#  'homePlayers_1_awayPlayers_8_Distance']

# %%
df_hp1.to_csv("/content/drive/My Drive/MCI Women_s Files/Jsonl_distance_with_ball_and_awayPlayers.csv",index=False)

# %%
df_hp1.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00                192194
# 1  [-11.08, 1.57, 0.0]                 0.00                192194
# 2  [-11.07, 1.59, 0.0]                 0.53                192194
# 3  [-11.07, 1.61, 0.0]                 0.60                192194
# 4  [-11.05, 1.63, 0.0]                 0.64                192194
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
#
#     homePlayers_3_xyz  ...  awayPlayers_1_position  awayPlayers_8_position  \
# 0  [-2.71, 8.54, 0.0]  ...                      MF                      MF
# 1  [-2.71, 8.52, 0.0]  ...                      MF                      MF
# 2   [-2.71, 8.5, 0.0]  ...                      MF                      MF
# 3  [-2.72, 8.48, 0.0]  ...                      MF                      MF
# 4  [-2.72, 8.46, 0.0]  ...                      MF                      MF
#
#   period  frameIdx gameClock      wallClock  \
# 0      1         0      0.00  1676118667880
# 1      1         1      0.04  1676118667920
# 2      1         2      0.08  1676118667960
# 3      1         3      0.12  1676118668000
# 4      1         4      0.16  1676118668040
#
#    homePlayers_1_homePlayers_3_Distance  homePlayers_1_homePlayers_5_Distance  \
# 0                             10.904907                             18.389521
# 1                             10.879311                             18.387224
# 2                             10.846091                             18.371154
# 3                             10.812927                             18.363575
# 4                             10.772084                             18.342260
#
#    homePlayers_1_awayPlayers_1_Distance homePlayers_1_awayPlayers_8_Distance
# 0                             22.967081                            26.290093
# 1                             22.982100                            26.277110
# 2                             22.980585                            26.244378
# 3                             22.988736                            26.213195
# 4                             22.970810                            26.170594
#
# [5 rows x 43 columns]

# %%
df_hp1.isna().sum()
# Out:
# homePlayers_1_playerId                  0
# homePlayers_1_number                    0
# homePlayers_1_xyz                       0
# homePlayers_1_speed                     0
# homePlayers_1_optaId                    0
# homePlayers_1_ballDistance              0
# homePlayers_1_position                  0
# homePlayers_3_playerId                  0
# homePlayers_3_number                    0
# homePlayers_3_xyz                       0
# homePlayers_3_speed                     0
# homePlayers_3_optaId                    0
# homePlayers_5_playerId                  0
# homePlayers_5_number                    0
# homePlayers_5_xyz                       0
# homePlayers_5_speed                     0
# homePlayers_5_optaId                    0
# homePlayers_3_ballDistance              0
# homePlayers_5_ballDistance              0
# homePlayers_3_position                  0
# homePlayers_5_position                  0
# awayPlayers_1_playerId                  0
# awayPlayers_1_number                    0
# awayPlayers_1_xyz                       0
# awayPlayers_1_speed                     0
# awayPlayers_1_optaId                    0
# awayPlayers_8_playerId                  0
# awayPlayers_8_number                    0
# awayPlayers_8_xyz                       0
# awayPlayers_8_speed                     0
# awayPlayers_8_optaId                    0
# awayPlayers_1_ballDistance              0
# awayPlayers_8_ballDistance              0
# awayPlayers_1_position                  0
# awayPlayers_8_position                  0
# period                                  0
# frameIdx                                0
# gameClock                               0
# wallClock                               0
# homePlayers_1_homePlayers_3_Distance    0
# homePlayers_1_homePlayers_5_Distance    0
# homePlayers_1_awayPlayers_1_Distance    0
# homePlayers_1_awayPlayers_8_Distance    0
# dtype: int64

# %%
df_hp1.shape
# Out:
# (151605, 43)

# %%
def get_x(pos):
  x = ast.literal_eval(pos)[0]
  return x

# %%
df_hp1["homePlayers_1_x"] = df_hp1["homePlayers_1_xyz"].apply(get_x)

# %% [markdown]
# **Filter DF**

# %%
filtered_df = df_hp1.where(df_hp1["homePlayers_1_x"].between(-40,40))
filtered_df.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00              192194.0
# 1  [-11.08, 1.57, 0.0]                 0.00              192194.0
# 2  [-11.07, 1.59, 0.0]                 0.53              192194.0
# 3  [-11.07, 1.61, 0.0]                 0.60              192194.0
# 4  [-11.05, 1.63, 0.0]                 0.64              192194.0
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
#
#     homePlayers_3_xyz  ...  awayPlayers_8_position  period frameIdx  \
# 0  [-2.71, 8.54, 0.0]  ...                      MF     1.0      0.0
# 1  [-2.71, 8.52, 0.0]  ...                      MF     1.0      1.0
# 2   [-2.71, 8.5, 0.0]  ...                      MF     1.0      2.0
# 3  [-2.72, 8.48, 0.0]  ...                      MF     1.0      3.0
# 4  [-2.72, 8.46, 0.0]  ...                      MF     1.0      4.0
#
#    gameClock     wallClock  homePlayers_1_homePlayers_3_Distance  \
# 0       0.00  1.676119e+12                             10.904907
# 1       0.04  1.676119e+12                             10.879311
# 2       0.08  1.676119e+12                             10.846091
# 3       0.12  1.676119e+12                             10.812927
# 4       0.16  1.676119e+12                             10.772084
#
#    homePlayers_1_homePlayers_5_Distance  homePlayers_1_awayPlayers_1_Distance  \
# 0                             18.389521                             22.967081
# 1                             18.387224                             22.982100
# 2                             18.371154                             22.980585
# 3                             18.363575                             22.988736
# 4                             18.342260                             22.970810
#
#    homePlayers_1_awayPlayers_8_Distance homePlayers_1_x
# 0                             26.290093          -11.08
# 1                             26.277110          -11.08
# 2                             26.244378          -11.07
# 3                             26.213195          -11.07
# 4                             26.170594          -11.05
#
# [5 rows x 44 columns]

# %%
list(filtered_df.columns)
# Out:
# ['homePlayers_1_playerId',
#  'homePlayers_1_number',
#  'homePlayers_1_xyz',
#  'homePlayers_1_speed',
#  'homePlayers_1_optaId',
#  'homePlayers_1_ballDistance',
#  'homePlayers_1_position',
#  'homePlayers_3_playerId',
#  'homePlayers_3_number',
#  'homePlayers_3_xyz',
#  'homePlayers_3_speed',
#  'homePlayers_3_optaId',
#  'homePlayers_5_playerId',
#  'homePlayers_5_number',
#  'homePlayers_5_xyz',
#  'homePlayers_5_speed',
#  'homePlayers_5_optaId',
#  'homePlayers_3_ballDistance',
#  'homePlayers_5_ballDistance',
#  'homePlayers_3_position',
#  'homePlayers_5_position',
#  'awayPlayers_1_playerId',
#  'awayPlayers_1_number',
#  'awayPlayers_1_xyz',
#  'awayPlayers_1_speed',
#  'awayPlayers_1_optaId',
#  'awayPlayers_8_playerId',
#  'awayPlayers_8_number',
#  'awayPlayers_8_xyz',
#  'awayPlayers_8_speed',
#  'awayPlayers_8_optaId',
#  'awayPlayers_1_ballDistance',
#  'awayPlayers_8_ballDistance',
#  'awayPlayers_1_position',
#  'awayPlayers_8_position',
#  'period',
#  'frameIdx',
#  'gameClock',
#  'wallClock',
#  'homePlayers_1_homePlayers_3_Distance',
#  'homePlayers_1_homePlayers_5_Distance',
#  'homePlayers_1_awayPlayers_1_Distance',
#  'homePlayers_1_awayPlayers_8_Distance',
#  'homePlayers_1_x']

# %%
filtered_df.shape
# Out:
# (151605, 44)

# %%
filtered_df = filtered_df.dropna()
filtered_df.shape
# Out:
# (146818, 44)

# %% [markdown]
# **Clustering**

# %%
cluster_cols = ['homePlayers_1_ballDistance',
                'homePlayers_1_speed',
                'homePlayers_1_homePlayers_3_Distance',
                'homePlayers_1_homePlayers_5_Distance',
                'homePlayers_1_awayPlayers_1_Distance',
                'homePlayers_1_awayPlayers_8_Distance']

# %%
cluster_df = filtered_df[cluster_cols]
cluster_df.head()
# Out:
#    homePlayers_1_ballDistance  homePlayers_1_speed  \
# 0                   10.857260                 0.00
# 1                   10.348435                 0.00
# 2                    9.815141                 0.53
# 3                    9.347347                 0.60
# 4                    8.831308                 0.64
#
#    homePlayers_1_homePlayers_3_Distance  homePlayers_1_homePlayers_5_Distance  \
# 0                             10.904907                             18.389521
# 1                             10.879311                             18.387224
# 2                             10.846091                             18.371154
# 3                             10.812927                             18.363575
# 4                             10.772084                             18.342260
#
#    homePlayers_1_awayPlayers_1_Distance  homePlayers_1_awayPlayers_8_Distance
# 0                             22.967081                             26.290093
# 1                             22.982100                             26.277110
# 2                             22.980585                             26.244378
# 3                             22.988736                             26.213195
# 4                             22.970810                             26.170594

# %%
cluster_df.describe()
# Out:
#        homePlayers_1_ballDistance  homePlayers_1_speed  \
# count               146818.000000        146818.000000
# mean                    19.668203             1.872963
# std                      9.894043             1.432449
# min                      0.010000             0.000000
# 25%                     12.273134             0.740000
# 50%                     19.531476             1.500000
# 75%                     26.478024             2.940000
# max                     69.501370             7.830000
#
#        homePlayers_1_homePlayers_3_Distance  \
# count                         146818.000000
# mean                              16.994513
# std                                8.856411
# min                                0.215870
# 25%                               10.789782
# 50%                               15.464138
# 75%                               21.683662
# max                               56.336263
#
#        homePlayers_1_homePlayers_5_Distance  \
# count                         146818.000000
# mean                              13.518970
# std                                6.686803
# min                                0.114018
# 25%                                8.783901
# 50%                               12.406309
# 75%                               17.024844
# max                               46.395264
#
#        homePlayers_1_awayPlayers_1_Distance  \
# count                         146818.000000
# mean                              11.971258
# std                                8.042733
# min                                0.125300
# 25%                                5.745964
# 50%                               10.189303
# 75%                               16.262208
# max                               42.402509
#
#        homePlayers_1_awayPlayers_8_Distance
# count                         146818.000000
# mean                              19.508846
# std                               12.037828
# min                                0.349285
# 25%                               11.938677
# 50%                               16.012573
# 75%                               22.411586
# max                               66.319672

# %%
cluster_df["homePlayers_1_speed"].isna().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in cluster_df.columns:
  plt.figure(figsize=(8,5))
  sns.boxplot(y=col, data=cluster_df)
  plt.show()

# %%
def impute_outliers_iqr(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    dataframe[column] = np.where(dataframe[column] < lower_bound, lower_bound, dataframe[column])
    dataframe[column] = np.where(dataframe[column] > upper_bound, upper_bound, dataframe[column])
    return dataframe

# %%
for col in cluster_df.columns:
  if "speed" in col:
    continue
  cluster_df = impute_outliers_iqr(cluster_df,col)

# %%
for col in cluster_df.columns:
  plt.figure(figsize=(8,5))
  sns.boxplot(y=col, data=cluster_df)
  plt.show()

# %% [markdown]
# **Inverse Distance from Away Player so that distance from home player is minimum and inverse of distance from away player is minimum. This allows clustering analysis to form clusters having low distance from home players and further distance from away players.**

# %%
cluster_df["homePlayers_1_awayPlayers_1_Distance"] = cluster_df["homePlayers_1_awayPlayers_1_Distance"].apply(lambda x: 1/x)
cluster_df["homePlayers_1_awayPlayers_8_Distance"] = cluster_df["homePlayers_1_awayPlayers_8_Distance"].apply(lambda x: 1/x)

# %%
print("Max Speed : {0}, Min Speed : {1}".format(max(cluster_df["homePlayers_1_speed"]), min(cluster_df["homePlayers_1_speed"])))
# Out:
# Max Speed : 7.83, Min Speed : 0.0

# %%
try:
  cluster_df["homePlayers_1_speed"] = cluster_df["homePlayers_1_speed"].apply(lambda x: 1/x)
except ZeroDivisionError:
  cluster_df["homePlayers_1_speed"] = cluster_df["homePlayers_1_speed"].apply(lambda x: (1/(x+0.1)))

# %%
cluster_df["homePlayers_1_homePlayers_3_Distance"] = cluster_df["homePlayers_1_homePlayers_3_Distance"].apply(lambda x: x/10)
cluster_df["homePlayers_1_homePlayers_5_Distance"] = cluster_df["homePlayers_1_homePlayers_5_Distance"].apply(lambda x: x/10)

# %%
cluster_df.describe()
# Out:
#        homePlayers_1_ballDistance  homePlayers_1_speed  \
# count               146818.000000        146818.000000
# mean                    19.655946             1.467796
# std                      9.847248             2.241316
# min                      0.010000             0.126103
# 25%                     12.273134             0.328947
# 50%                     19.531476             0.625000
# 75%                     26.478024             1.190476
# max                     47.785358            10.000000
#
#        homePlayers_1_homePlayers_3_Distance  \
# count                         146818.000000
# mean                               1.674774
# std                                0.806801
# min                                0.021587
# 25%                                1.078978
# 50%                                1.546414
# 75%                                2.168366
# max                                3.802448
#
#        homePlayers_1_homePlayers_5_Distance  \
# count                         146818.000000
# mean                               1.341483
# std                                0.637520
# min                                0.011402
# 25%                                0.878390
# 50%                                1.240631
# 75%                                1.702484
# max                                2.938626
#
#        homePlayers_1_awayPlayers_1_Distance  \
# count                         146818.000000
# mean                               0.160732
# std                                0.214483
# min                                0.031214
# 25%                                0.061492
# 50%                                0.098142
# 75%                                0.174035
# max                                7.980869
#
#        homePlayers_1_awayPlayers_8_Distance
# count                         146818.000000
# mean                               0.077172
# std                                0.088898
# min                                0.026232
# 25%                                0.044620
# 50%                                0.062451
# 75%                                0.083761
# max                                2.862992

# %%
for col in cluster_df.columns:
  plt.figure(figsize=(8,5))
  sns.boxplot(y=col, data=cluster_df)
  plt.show()

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(cluster_df)

# %% [markdown]
# **Clustering**

# %%
from sklearn.cluster import KMeans

# %%
# wcss = []
# for k in range(1, 101):
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(scaled_df)
#     wcss.append(kmeans.inertia_)
    
# # Plot the results
# plt.plot(range(1, 101), wcss)
# plt.title('Elbow Method')
# plt.xlabel('Number of clusters')
# plt.ylabel('WCSS')
# plt.show()

# %%
# wcss = []
# for k in range(1, 11):
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(scaled_df)
#     wcss.append(kmeans.inertia_)
    
# # Plot the results
# plt.plot(range(1, 11), wcss)
# plt.title('Elbow Method')
# plt.xlabel('Number of clusters')
# plt.ylabel('WCSS')
# plt.show()

# %%
wcss = []
for k in range(1, 31):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(cluster_df)
    wcss.append(kmeans.inertia_)
    
# Plot the results
plt.plot(range(1, 31), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# kmeans = KMeans(n_clusters=5, random_state=42)
# kmeans.fit(scaled_df)
# labels = kmeans.labels_
# labels

# %%
# from sklearn.metrics import silhouette_score

# silhouette_avg = silhouette_score(scaled_df, labels)
# print('Silhouette score:', silhouette_avg)

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(cluster_df)
labels = kmeans.labels_
labels
# Out:
# array([4, 4, 4, ..., 0, 0, 0], dtype=int32)

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(cluster_df, labels)
print('Silhouette score:', silhouette_avg)
# Out:
# Silhouette score: 0.40172254009660313

# %%
cluster_df_copy = cluster_df.copy()
cluster_df_copy.head()
# Out:
#    homePlayers_1_ballDistance  homePlayers_1_speed  \
# 0                   10.857260            10.000000
# 1                   10.348435            10.000000
# 2                    9.815141             1.587302
# 3                    9.347347             1.428571
# 4                    8.831308             1.351351
#
#    homePlayers_1_homePlayers_3_Distance  homePlayers_1_homePlayers_5_Distance  \
# 0                              1.090491                              1.838952
# 1                              1.087931                              1.838722
# 2                              1.084609                              1.837115
# 3                              1.081293                              1.836358
# 4                              1.077208                              1.834226
#
#    homePlayers_1_awayPlayers_1_Distance  homePlayers_1_awayPlayers_8_Distance
# 0                              0.043541                              0.038037
# 1                              0.043512                              0.038056
# 2                              0.043515                              0.038103
# 3                              0.043500                              0.038149
# 4                              0.043534                              0.038211

# %%
cluster_df.columns
# Out:
# Index(['homePlayers_1_ballDistance', 'homePlayers_1_speed',
#        'homePlayers_1_homePlayers_3_Distance',
#        'homePlayers_1_homePlayers_5_Distance',
#        'homePlayers_1_awayPlayers_1_Distance',
#        'homePlayers_1_awayPlayers_8_Distance'],
#       dtype='object')

# %%
cluster_df_copy["Cluster"] = labels
cluster_df_copy.head()
# Out:
#    homePlayers_1_ballDistance  homePlayers_1_speed  \
# 0                   10.857260            10.000000
# 1                   10.348435            10.000000
# 2                    9.815141             1.587302
# 3                    9.347347             1.428571
# 4                    8.831308             1.351351
#
#    homePlayers_1_homePlayers_3_Distance  homePlayers_1_homePlayers_5_Distance  \
# 0                              1.090491                              1.838952
# 1                              1.087931                              1.838722
# 2                              1.084609                              1.837115
# 3                              1.081293                              1.836358
# 4                              1.077208                              1.834226
#
#    homePlayers_1_awayPlayers_1_Distance  homePlayers_1_awayPlayers_8_Distance  \
# 0                              0.043541                              0.038037
# 1                              0.043512                              0.038056
# 2                              0.043515                              0.038103
# 3                              0.043500                              0.038149
# 4                              0.043534                              0.038211
#
#    Cluster
# 0        4
# 1        4
# 2        4
# 3        4
# 4        1

# %%
columns_new = {'homePlayers_1_ballDistance': 'ballDis', 
               'homePlayers_1_speed': 'Speed', 
               'homePlayers_1_homePlayers_3_Distance': 'hp3Dis',
               'homePlayers_1_homePlayers_5_Distance': 'hp5Dis',
               'homePlayers_1_awayPlayers_1_Distance': 'ap1Dis',
               'homePlayers_1_awayPlayers_8_Distance': 'ap8Dis',}

# %%
cluster_df_copy = cluster_df_copy.rename(columns=columns_new)

# %%
cluster_df_copy.describe()
# Out:
#              ballDis          Speed         hp3Dis         hp5Dis  \
# count  146818.000000  146818.000000  146818.000000  146818.000000
# mean       19.655946       1.467796       1.674774       1.341483
# std         9.847248       2.241316       0.806801       0.637520
# min         0.010000       0.126103       0.021587       0.011402
# 25%        12.273134       0.328947       1.078978       0.878390
# 50%        19.531476       0.625000       1.546414       1.240631
# 75%        26.478024       1.190476       2.168366       1.702484
# max        47.785358      10.000000       3.802448       2.938626
#
#               ap1Dis         ap8Dis        Cluster
# count  146818.000000  146818.000000  146818.000000
# mean        0.160732       0.077172       2.202625
# std         0.214483       0.088898       1.483648
# min         0.031214       0.026232       0.000000
# 25%         0.061492       0.044620       1.000000
# 50%         0.098142       0.062451       3.000000
# 75%         0.174035       0.083761       4.000000
# max         7.980869       2.862992       4.000000

# %%
for i in range(5):
  print("Cluster {}".format(i))
  temp_df = cluster_df_copy[cluster_df_copy["Cluster"]==i]
  print(temp_df.describe())
  print("______________________________________________")
# Out:
# Cluster 0
#             ballDis         Speed        hp3Dis        hp5Dis        ap1Dis  \
# count  29926.000000  29926.000000  29926.000000  29926.000000  29926.000000
# mean      27.497536      1.764017      1.742974      1.408604      0.141436
# std        2.267929      2.431420      0.814303      0.658031      0.168317
# min       23.618171      0.158479      0.097944      0.065192      0.031214
# 25%       25.551159      0.353357      1.138752      0.946610      0.053563
# 50%       27.204133      0.800000      1.620032      1.274146      0.088049
# 75%       29.415880      1.639344      2.324553      1.758424      0.161923
# max       31.914092     10.000000      3.802448      2.938626      2.258770
#
#              ap8Dis  Cluster
# count  29926.000000  29926.0
# mean       0.069707      0.0
# std        0.048253      0.0
# min        0.026232      0.0
# 25%        0.046679      0.0
# 50%        0.061686      0.0
# 75%        0.078592      0.0
# max        1.407195      0.0
# ______________________________________________
# Cluster 1
#             ballDis         Speed        hp3Dis        hp5Dis        ap1Dis  \
# count  22917.000000  22917.000000  22917.000000  22917.000000  22917.000000
# mean       5.090585      1.482801      1.599576      1.164456      0.185485
# std        2.707203      2.423374      0.752160      0.572702      0.292661
# min        0.010000      0.142857      0.090554      0.127016      0.031214
# 25%        2.779137      0.304878      1.023369      0.702727      0.067251
# 50%        5.306317      0.507614      1.534008      1.132167      0.100185
# 75%        7.370346      1.030928      2.142276      1.484266      0.164260
# max        9.442230     10.000000      3.802448      2.938626      3.763550
#
#              ap8Dis  Cluster
# count  22917.000000  22917.0
# mean       0.107249      1.0
# std        0.175734      0.0
# min        0.026232      1.0
# 25%        0.044218      1.0
# 50%        0.065382      1.0
# 75%        0.102855      1.0
# max        2.862992      1.0
# ______________________________________________
# Cluster 2
#             ballDis         Speed        hp3Dis        hp5Dis        ap1Dis  \
# count  18489.000000  18489.000000  18489.000000  18489.000000  18489.000000
# mean      36.194035      2.056471      1.655439      1.538403      0.135287
# std        3.756033      2.680375      0.851032      0.748311      0.144965
# min       31.748110      0.163934      0.026420      0.011402      0.031214
# 25%       33.234917      0.414938      1.113338      0.994421      0.042727
# 50%       35.396092      0.877193      1.565593      1.386706      0.082069
# 75%       37.747165      2.127660      2.150186      2.105542      0.162003
# max       47.785358     10.000000      3.802448      2.938626      1.403448
#
#              ap8Dis  Cluster
# count  18489.000000  18489.0
# mean       0.062026      2.0
# std        0.034435      0.0
# min        0.026232      2.0
# 25%        0.033804      2.0
# 50%        0.055927      2.0
# 75%        0.081048      2.0
# max        0.296578      2.0
# ______________________________________________
# Cluster 3
#             ballDis         Speed        hp3Dis        hp5Dis        ap1Dis  \
# count  38454.000000  38454.000000  38454.000000  38454.000000  38454.000000
# mean      20.495811      1.433622      1.700939      1.360916      0.152674
# std        1.997956      2.166541      0.860023      0.624725      0.215285
# min       16.354978      0.129199      0.021587      0.100499      0.031214
# 25%       18.767805      0.328947      1.045782      0.883338      0.061725
# 50%       20.586558      0.636943      1.535486      1.267896      0.095957
# 75%       22.225294      1.111111      2.196578      1.774405      0.166970
# max       24.049726     10.000000      3.802448      2.938626      7.980869
#
#              ap8Dis  Cluster
# count  38454.000000  38454.0
# mean       0.069336      3.0
# std        0.058691      0.0
# min        0.026232      3.0
# 25%        0.045527      3.0
# 50%        0.060984      3.0
# 75%        0.079730      3.0
# max        2.076137      3.0
# ______________________________________________
# Cluster 4
#             ballDis         Speed        hp3Dis        hp5Dis        ap1Dis  \
# count  37032.000000  37032.000000  37032.000000  37032.000000  37032.000000
# mean      13.203637      0.960706      1.648681      1.278300      0.182079
# std        2.159255      1.594244      0.745870      0.571736      0.215281
# min        9.057329      0.126103      0.320740      0.214611      0.031214
# 25%       11.448437      0.309598      1.084780      0.858464      0.074916
# 50%       13.259551      0.497512      1.516673      1.189271      0.112130
# 75%       15.019541      0.826446      2.087019      1.576413      0.210187
# max       16.903615     10.000000      3.802448      2.938626      2.544933
#
#              ap8Dis  Cluster
# count  37032.000000  37032.0
# mean       0.080291      4.0
# std        0.073337      0.0
# min        0.026232      4.0
# 25%        0.047768      4.0
# 50%        0.066854      4.0
# 75%        0.089434      4.0
# max        2.049370      4.0
# ______________________________________________

# %%
performance = {0:"Below Average",
               1:"Best",
               2:"Poor",
               3:"Average",
               4:"Good"}

# %%
cluster_df_copy["Cluster"] = cluster_df_copy["Cluster"].replace(performance)

# %%
filtered_df.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                  25.0
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00              192194.0
# 1  [-11.08, 1.57, 0.0]                 0.00              192194.0
# 2  [-11.07, 1.59, 0.0]                 0.53              192194.0
# 3  [-11.07, 1.61, 0.0]                 0.60              192194.0
# 4  [-11.05, 1.63, 0.0]                 0.64              192194.0
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                   7.0
#
#     homePlayers_3_xyz  ...  awayPlayers_8_position  period frameIdx  \
# 0  [-2.71, 8.54, 0.0]  ...                      MF     1.0      0.0
# 1  [-2.71, 8.52, 0.0]  ...                      MF     1.0      1.0
# 2   [-2.71, 8.5, 0.0]  ...                      MF     1.0      2.0
# 3  [-2.72, 8.48, 0.0]  ...                      MF     1.0      3.0
# 4  [-2.72, 8.46, 0.0]  ...                      MF     1.0      4.0
#
#    gameClock     wallClock  homePlayers_1_homePlayers_3_Distance  \
# 0       0.00  1.676119e+12                             10.904907
# 1       0.04  1.676119e+12                             10.879311
# 2       0.08  1.676119e+12                             10.846091
# 3       0.12  1.676119e+12                             10.812927
# 4       0.16  1.676119e+12                             10.772084
#
#    homePlayers_1_homePlayers_5_Distance  homePlayers_1_awayPlayers_1_Distance  \
# 0                             18.389521                             22.967081
# 1                             18.387224                             22.982100
# 2                             18.371154                             22.980585
# 3                             18.363575                             22.988736
# 4                             18.342260                             22.970810
#
#    homePlayers_1_awayPlayers_8_Distance homePlayers_1_x
# 0                             26.290093          -11.08
# 1                             26.277110          -11.08
# 2                             26.244378          -11.07
# 3                             26.213195          -11.07
# 4                             26.170594          -11.05
#
# [5 rows x 44 columns]

# %%
filtered_df["Performance"] = cluster_df_copy["Cluster"]

# %%
result = filtered_df[["period","gameClock","Performance"]]

# %%
result["Performance"].value_counts().sort_values(ascending=False)
# Out:
# Average          38454
# Good             37032
# Below Average    29926
# Best             22917
# Poor             18489
# Name: Performance, dtype: int64

# %%
result.shape
# Out:
# (146818, 3)

# %%
result.head(20)
# Out:
#     period  gameClock Performance
# 0      1.0       0.00        Good
# 1      1.0       0.04        Good
# 2      1.0       0.08        Good
# 3      1.0       0.12        Good
# 4      1.0       0.16        Best
# 5      1.0       0.20        Best
# 6      1.0       0.24        Best
# 7      1.0       0.28        Best
# 8      1.0       0.32        Best
# 9      1.0       0.36        Best
# 10     1.0       0.40        Best
# 11     1.0       0.44        Best
# 12     1.0       0.48        Best
# 13     1.0       0.52        Best
# 14     1.0       0.56        Best
# 15     1.0       0.60        Best
# 16     1.0       0.64        Best
# 17     1.0       0.68        Best
# 18     1.0       0.72        Best
# 19     1.0       0.76        Best

# %% [markdown]
# **Combine Result With Original Dataframe of homeplayer 1**

# %%
result["joinKey"] = result["period"].astype(str) + "_" + result["gameClock"].astype(str)
result.head()
# Out:
#    period  gameClock Performance   joinKey
# 0     1.0       0.00        Good   1.0_0.0
# 1     1.0       0.04        Good  1.0_0.04
# 2     1.0       0.08        Good  1.0_0.08
# 3     1.0       0.12        Good  1.0_0.12
# 4     1.0       0.16        Best  1.0_0.16

# %%
df_hp1["joinKey"] = df_hp1["period"].astype('float').astype(str) + "_" + df_hp1["gameClock"].astype(str)
df_hp1.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00                192194
# 1  [-11.08, 1.57, 0.0]                 0.00                192194
# 2  [-11.07, 1.59, 0.0]                 0.53                192194
# 3  [-11.07, 1.61, 0.0]                 0.60                192194
# 4  [-11.05, 1.63, 0.0]                 0.64                192194
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
#
#     homePlayers_3_xyz  ...  period  frameIdx gameClock      wallClock  \
# 0  [-2.71, 8.54, 0.0]  ...       1         0      0.00  1676118667880
# 1  [-2.71, 8.52, 0.0]  ...       1         1      0.04  1676118667920
# 2   [-2.71, 8.5, 0.0]  ...       1         2      0.08  1676118667960
# 3  [-2.72, 8.48, 0.0]  ...       1         3      0.12  1676118668000
# 4  [-2.72, 8.46, 0.0]  ...       1         4      0.16  1676118668040
#
#   homePlayers_1_homePlayers_3_Distance  homePlayers_1_homePlayers_5_Distance  \
# 0                            10.904907                             18.389521
# 1                            10.879311                             18.387224
# 2                            10.846091                             18.371154
# 3                            10.812927                             18.363575
# 4                            10.772084                             18.342260
#
#    homePlayers_1_awayPlayers_1_Distance  homePlayers_1_awayPlayers_8_Distance  \
# 0                             22.967081                             26.290093
# 1                             22.982100                             26.277110
# 2                             22.980585                             26.244378
# 3                             22.988736                             26.213195
# 4                             22.970810                             26.170594
#
#    homePlayers_1_x   joinKey
# 0           -11.08   1.0_0.0
# 1           -11.08  1.0_0.04
# 2           -11.07  1.0_0.08
# 3           -11.07  1.0_0.12
# 4           -11.05  1.0_0.16
#
# [5 rows x 45 columns]

# %%
final_df = pd.merge(df_hp1, result, on='joinKey', how='left')
final_df.head()
# Out:
#                  homePlayers_1_playerId  homePlayers_1_number  \
# 0  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 1  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 2  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 3  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
# 4  0746befc-a701-4b33-8faf-b3cccccf17bb                    25
#
#      homePlayers_1_xyz  homePlayers_1_speed  homePlayers_1_optaId  \
# 0  [-11.08, 1.55, 0.0]                 0.00                192194
# 1  [-11.08, 1.57, 0.0]                 0.00                192194
# 2  [-11.07, 1.59, 0.0]                 0.53                192194
# 3  [-11.07, 1.61, 0.0]                 0.60                192194
# 4  [-11.05, 1.63, 0.0]                 0.64                192194
#
#    homePlayers_1_ballDistance homePlayers_1_position  \
# 0                   10.857260                     MF
# 1                   10.348435                     MF
# 2                    9.815141                     MF
# 3                    9.347347                     MF
# 4                    8.831308                     MF
#
#                  homePlayers_3_playerId  homePlayers_3_number  \
# 0  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 1  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 2  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 3  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
# 4  1ab5dc11-1e32-4e6b-a385-5b736ec14763                     7
#
#     homePlayers_3_xyz  ...      wallClock  \
# 0  [-2.71, 8.54, 0.0]  ...  1676118667880
# 1  [-2.71, 8.52, 0.0]  ...  1676118667920
# 2   [-2.71, 8.5, 0.0]  ...  1676118667960
# 3  [-2.72, 8.48, 0.0]  ...  1676118668000
# 4  [-2.72, 8.46, 0.0]  ...  1676118668040
#
#    homePlayers_1_homePlayers_3_Distance homePlayers_1_homePlayers_5_Distance  \
# 0                             10.904907                            18.389521
# 1                             10.879311                            18.387224
# 2                             10.846091                            18.371154
# 3                             10.812927                            18.363575
# 4                             10.772084                            18.342260
#
#    homePlayers_1_awayPlayers_1_Distance homePlayers_1_awayPlayers_8_Distance  \
# 0                             22.967081                            26.290093
# 1                             22.982100                            26.277110
# 2                             22.980585                            26.244378
# 3                             22.988736                            26.213195
# 4                             22.970810                            26.170594
#
#    homePlayers_1_x   joinKey  period_y  gameClock_y Performance
# 0           -11.08   1.0_0.0       1.0         0.00        Good
# 1           -11.08  1.0_0.04       1.0         0.04        Good
# 2           -11.07  1.0_0.08       1.0         0.08        Good
# 3           -11.07  1.0_0.12       1.0         0.12        Good
# 4           -11.05  1.0_0.16       1.0         0.16        Best
#
# [5 rows x 48 columns]

# %%
list(final_df.columns)
# Out:
# ['homePlayers_1_playerId',
#  'homePlayers_1_number',
#  'homePlayers_1_xyz',
#  'homePlayers_1_speed',
#  'homePlayers_1_optaId',
#  'homePlayers_1_ballDistance',
#  'homePlayers_1_position',
#  'homePlayers_3_playerId',
#  'homePlayers_3_number',
#  'homePlayers_3_xyz',
#  'homePlayers_3_speed',
#  'homePlayers_3_optaId',
#  'homePlayers_5_playerId',
#  'homePlayers_5_number',
#  'homePlayers_5_xyz',
#  'homePlayers_5_speed',
#  'homePlayers_5_optaId',
#  'homePlayers_3_ballDistance',
#  'homePlayers_5_ballDistance',
#  'homePlayers_3_position',
#  'homePlayers_5_position',
#  'awayPlayers_1_playerId',
#  'awayPlayers_1_number',
#  'awayPlayers_1_xyz',
#  'awayPlayers_1_speed',
#  'awayPlayers_1_optaId',
#  'awayPlayers_8_playerId',
#  'awayPlayers_8_number',
#  'awayPlayers_8_xyz',
#  'awayPlayers_8_speed',
#  'awayPlayers_8_optaId',
#  'awayPlayers_1_ballDistance',
#  'awayPlayers_8_ballDistance',
#  'awayPlayers_1_position',
#  'awayPlayers_8_position',
#  'period_x',
#  'frameIdx',
#  'gameClock_x',
#  'wallClock',
#  'homePlayers_1_homePlayers_3_Distance',
#  'homePlayers_1_homePlayers_5_Distance',
#  'homePlayers_1_awayPlayers_1_Distance',
#  'homePlayers_1_awayPlayers_8_Distance',
#  'homePlayers_1_x',
#  'joinKey',
#  'period_y',
#  'gameClock_y',
#  'Performance']

# %%
final_cols = ['period_x',
              'gameClock_x',
              'homePlayers_1_number',
              'homePlayers_1_xyz',
              'homePlayers_1_ballDistance',
              'homePlayers_1_speed',
              'homePlayers_3_xyz',
              'homePlayers_1_homePlayers_3_Distance',
              'homePlayers_5_xyz',
              'homePlayers_1_homePlayers_5_Distance',
              'awayPlayers_1_xyz',
              'homePlayers_1_awayPlayers_1_Distance',
              'awayPlayers_8_xyz',
              'homePlayers_1_awayPlayers_8_Distance',
              'Performance']

# %%
final_df = final_df[final_cols]
final_df.head()
# Out:
#    period_x  gameClock_x  homePlayers_1_number    homePlayers_1_xyz  \
# 0         1         0.00                    25  [-11.08, 1.55, 0.0]
# 1         1         0.04                    25  [-11.08, 1.57, 0.0]
# 2         1         0.08                    25  [-11.07, 1.59, 0.0]
# 3         1         0.12                    25  [-11.07, 1.61, 0.0]
# 4         1         0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance
# 0                             26.290093        Good
# 1                             26.277110        Good
# 2                             26.244378        Good
# 3                             26.213195        Good
# 4                             26.170594        Best

# %%
final_df = final_df.rename(columns={'period_x':'period','gameClock_x':'gameClock'})
final_df.head()
# Out:
#    period  gameClock  homePlayers_1_number    homePlayers_1_xyz  \
# 0       1       0.00                    25  [-11.08, 1.55, 0.0]
# 1       1       0.04                    25  [-11.08, 1.57, 0.0]
# 2       1       0.08                    25  [-11.07, 1.59, 0.0]
# 3       1       0.12                    25  [-11.07, 1.61, 0.0]
# 4       1       0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance
# 0                             26.290093        Good
# 1                             26.277110        Good
# 2                             26.244378        Good
# 3                             26.213195        Good
# 4                             26.170594        Best

# %%
final_df["Performance"].value_counts()
# Out:
# Average          38454
# Good             37032
# Below Average    29926
# Best             22917
# Poor             18489
# Name: Performance, dtype: int64

# %%
final_df["Performance"].isna().sum()
# Out:
# 4787

# %% [markdown]
# **First Half**

# %%
final_df1 = final_df[final_df["period"]==1]
final_df1.head()
# Out:
#    period  gameClock  homePlayers_1_number    homePlayers_1_xyz  \
# 0       1       0.00                    25  [-11.08, 1.55, 0.0]
# 1       1       0.04                    25  [-11.08, 1.57, 0.0]
# 2       1       0.08                    25  [-11.07, 1.59, 0.0]
# 3       1       0.12                    25  [-11.07, 1.61, 0.0]
# 4       1       0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance
# 0                             26.290093        Good
# 1                             26.277110        Good
# 2                             26.244378        Good
# 3                             26.213195        Good
# 4                             26.170594        Best

# %%
final_df1["Performance"].value_counts().sort_values(ascending=False)
# Out:
# Average          19851
# Good             19748
# Best             14411
# Below Average    13161
# Poor              7647
# Name: Performance, dtype: int64

# %%
final_df2 = final_df[final_df["period"]==2]
final_df2.head()
# Out:
#        period  gameClock  homePlayers_1_number  homePlayers_1_xyz  \
# 76667       2       0.00                    25  [8.95, 4.13, 0.0]
# 76668       2       0.04                    25  [8.95, 4.16, 0.0]
# 76669       2       0.08                    25  [8.95, 4.18, 0.0]
# 76670       2       0.12                    25  [8.94, 4.21, 0.0]
# 76671       2       0.16                    25  [8.94, 4.22, 0.0]
#
#        homePlayers_1_ballDistance  homePlayers_1_speed    homePlayers_3_xyz  \
# 76667                   10.330247                 0.00  [9.29, -10.76, 0.0]
# 76668                   10.602283                 0.00  [9.28, -10.75, 0.0]
# 76669                   10.953584                 0.58  [9.27, -10.74, 0.0]
# 76670                   11.333865                 0.55  [9.25, -10.72, 0.0]
# 76671                   11.845548                 0.65  [9.23, -10.71, 0.0]
#
#        homePlayers_1_homePlayers_3_Distance   homePlayers_5_xyz  \
# 76667                             14.893881   [6.9, 11.42, 0.0]
# 76668                             14.913651   [6.9, 11.42, 0.0]
# 76669                             14.923431   [6.9, 11.41, 0.0]
# 76670                             14.933218  [6.89, 11.41, 0.0]
# 76671                             14.932816  [6.88, 11.41, 0.0]
#
#        homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 76667                              7.572754  [-0.14, 10.02, 0.0]
# 76668                              7.543878  [-0.13, 10.01, 0.0]
# 76669                              7.515012   [-0.12, 10.0, 0.0]
# 76670                              7.486154   [-0.11, 10.0, 0.0]
# 76671                              7.479285    [-0.1, 9.99, 0.0]
#
#        homePlayers_1_awayPlayers_1_Distance    awayPlayers_8_xyz  \
# 76667                             10.831445  [-11.23, 0.01, 0.0]
# 76668                             10.801338  [-11.22, 0.02, 0.0]
# 76669                             10.776702  [-11.21, 0.05, 0.0]
# 76670                             10.743677  [-11.19, 0.07, 0.0]
# 76671                             10.724481  [-11.18, 0.09, 0.0]
#
#        homePlayers_1_awayPlayers_8_Distance Performance
# 76667                             20.596281        Good
# 76668                             20.590495        Good
# 76669                             20.578690        Good
# 76670                             20.551314        Good
# 76671                             20.539506        Good

# %%
final_df2["Performance"].value_counts().sort_values(ascending=False)
# Out:
# Average          18603
# Good             17284
# Below Average    16765
# Poor             10842
# Best              8506
# Name: Performance, dtype: int64

# %% [markdown]
# **5 minutes analysis**

# %%
final_df1["gameClock"].max()
# Out:
# 3066.64

# %%
bins = [i for i in range(0,3300,300)]
bins
# Out:
# [0, 300, 600, 900, 1200, 1500, 1800, 2100, 2400, 2700, 3000]

# %%
labels = ['0-5','5-10','10-15','15-20','20-25','25-30','30-35','35-40','40-45','Extra-Time']
labels
# Out:
# ['0-5',
#  '5-10',
#  '10-15',
#  '15-20',
#  '20-25',
#  '25-30',
#  '30-35',
#  '35-40',
#  '40-45',
#  'Extra-Time']

# %%
final_df1["fiveMins"] = pd.cut(final_df1['gameClock'], bins=bins, labels=labels)
final_df1.head()
# Out:
#    period  gameClock  homePlayers_1_number    homePlayers_1_xyz  \
# 0       1       0.00                    25  [-11.08, 1.55, 0.0]
# 1       1       0.04                    25  [-11.08, 1.57, 0.0]
# 2       1       0.08                    25  [-11.07, 1.59, 0.0]
# 3       1       0.12                    25  [-11.07, 1.61, 0.0]
# 4       1       0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance fiveMins
# 0                             26.290093        Good      NaN
# 1                             26.277110        Good      0-5
# 2                             26.244378        Good      0-5
# 3                             26.213195        Good      0-5
# 4                             26.170594        Best      0-5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

color_palette = sns.color_palette("RdYlGn", n_colors=5)
color_palette = list(reversed(color_palette))
plt.figure(figsize=(10,30))
sns.catplot(y='fiveMins', kind='count', hue='Performance', data=final_df1, 
            order=labels, hue_order=['Best', 'Good', 'Average','Below Average','Poor'], palette=color_palette)
plt.show()

# %%
final_df2.head()
# Out:
#        period  gameClock  homePlayers_1_number  homePlayers_1_xyz  \
# 76667       2       0.00                    25  [8.95, 4.13, 0.0]
# 76668       2       0.04                    25  [8.95, 4.16, 0.0]
# 76669       2       0.08                    25  [8.95, 4.18, 0.0]
# 76670       2       0.12                    25  [8.94, 4.21, 0.0]
# 76671       2       0.16                    25  [8.94, 4.22, 0.0]
#
#        homePlayers_1_ballDistance  homePlayers_1_speed    homePlayers_3_xyz  \
# 76667                   10.330247                 0.00  [9.29, -10.76, 0.0]
# 76668                   10.602283                 0.00  [9.28, -10.75, 0.0]
# 76669                   10.953584                 0.58  [9.27, -10.74, 0.0]
# 76670                   11.333865                 0.55  [9.25, -10.72, 0.0]
# 76671                   11.845548                 0.65  [9.23, -10.71, 0.0]
#
#        homePlayers_1_homePlayers_3_Distance   homePlayers_5_xyz  \
# 76667                             14.893881   [6.9, 11.42, 0.0]
# 76668                             14.913651   [6.9, 11.42, 0.0]
# 76669                             14.923431   [6.9, 11.41, 0.0]
# 76670                             14.933218  [6.89, 11.41, 0.0]
# 76671                             14.932816  [6.88, 11.41, 0.0]
#
#        homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 76667                              7.572754  [-0.14, 10.02, 0.0]
# 76668                              7.543878  [-0.13, 10.01, 0.0]
# 76669                              7.515012   [-0.12, 10.0, 0.0]
# 76670                              7.486154   [-0.11, 10.0, 0.0]
# 76671                              7.479285    [-0.1, 9.99, 0.0]
#
#        homePlayers_1_awayPlayers_1_Distance    awayPlayers_8_xyz  \
# 76667                             10.831445  [-11.23, 0.01, 0.0]
# 76668                             10.801338  [-11.22, 0.02, 0.0]
# 76669                             10.776702  [-11.21, 0.05, 0.0]
# 76670                             10.743677  [-11.19, 0.07, 0.0]
# 76671                             10.724481  [-11.18, 0.09, 0.0]
#
#        homePlayers_1_awayPlayers_8_Distance Performance
# 76667                             20.596281        Good
# 76668                             20.590495        Good
# 76669                             20.578690        Good
# 76670                             20.551314        Good
# 76671                             20.539506        Good

# %%
final_df2["gameClock"].max()
# Out:
# 2997.48

# %%
bins2 = [i for i in range(0,3000,300)]
bins2
# Out:
# [0, 300, 600, 900, 1200, 1500, 1800, 2100, 2400, 2700]

# %%
labels2 = ['45-50','50-55','55-60','60-65','65-70','70-75','75-80','80-85','85-90']
labels2
# Out:
# ['45-50',
#  '50-55',
#  '55-60',
#  '60-65',
#  '65-70',
#  '70-75',
#  '75-80',
#  '80-85',
#  '85-90']

# %%
final_df2["fiveMins"] = pd.cut(final_df2['gameClock'], bins=bins2, labels=labels2)
final_df2.head()
# Out:
#        period  gameClock  homePlayers_1_number  homePlayers_1_xyz  \
# 76667       2       0.00                    25  [8.95, 4.13, 0.0]
# 76668       2       0.04                    25  [8.95, 4.16, 0.0]
# 76669       2       0.08                    25  [8.95, 4.18, 0.0]
# 76670       2       0.12                    25  [8.94, 4.21, 0.0]
# 76671       2       0.16                    25  [8.94, 4.22, 0.0]
#
#        homePlayers_1_ballDistance  homePlayers_1_speed    homePlayers_3_xyz  \
# 76667                   10.330247                 0.00  [9.29, -10.76, 0.0]
# 76668                   10.602283                 0.00  [9.28, -10.75, 0.0]
# 76669                   10.953584                 0.58  [9.27, -10.74, 0.0]
# 76670                   11.333865                 0.55  [9.25, -10.72, 0.0]
# 76671                   11.845548                 0.65  [9.23, -10.71, 0.0]
#
#        homePlayers_1_homePlayers_3_Distance   homePlayers_5_xyz  \
# 76667                             14.893881   [6.9, 11.42, 0.0]
# 76668                             14.913651   [6.9, 11.42, 0.0]
# 76669                             14.923431   [6.9, 11.41, 0.0]
# 76670                             14.933218  [6.89, 11.41, 0.0]
# 76671                             14.932816  [6.88, 11.41, 0.0]
#
#        homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 76667                              7.572754  [-0.14, 10.02, 0.0]
# 76668                              7.543878  [-0.13, 10.01, 0.0]
# 76669                              7.515012   [-0.12, 10.0, 0.0]
# 76670                              7.486154   [-0.11, 10.0, 0.0]
# 76671                              7.479285    [-0.1, 9.99, 0.0]
#
#        homePlayers_1_awayPlayers_1_Distance    awayPlayers_8_xyz  \
# 76667                             10.831445  [-11.23, 0.01, 0.0]
# 76668                             10.801338  [-11.22, 0.02, 0.0]
# 76669                             10.776702  [-11.21, 0.05, 0.0]
# 76670                             10.743677  [-11.19, 0.07, 0.0]
# 76671                             10.724481  [-11.18, 0.09, 0.0]
#
#        homePlayers_1_awayPlayers_8_Distance Performance fiveMins
# 76667                             20.596281        Good      NaN
# 76668                             20.590495        Good    45-50
# 76669                             20.578690        Good    45-50
# 76670                             20.551314        Good    45-50
# 76671                             20.539506        Good    45-50

# %%
import seaborn as sns
import matplotlib.pyplot as plt

color_palette = sns.color_palette("RdYlGn", n_colors=5)
color_palette = list(reversed(color_palette))
plt.figure(figsize=(10,30))
sns.catplot(y='fiveMins', kind='count', hue='Performance', data=final_df2, 
            order=labels2, hue_order=['Best', 'Good', 'Average','Below Average','Poor'], palette=color_palette)
plt.show()

# %%
result_df = pd.concat([final_df1, final_df2], axis=0)
print(result_df.shape)
result_df.head()
# Out:
# (151605, 16)
#    period  gameClock  homePlayers_1_number    homePlayers_1_xyz  \
# 0       1       0.00                    25  [-11.08, 1.55, 0.0]
# 1       1       0.04                    25  [-11.08, 1.57, 0.0]
# 2       1       0.08                    25  [-11.07, 1.59, 0.0]
# 3       1       0.12                    25  [-11.07, 1.61, 0.0]
# 4       1       0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance fiveMins
# 0                             26.290093        Good      NaN
# 1                             26.277110        Good      0-5
# 2                             26.244378        Good      0-5
# 3                             26.213195        Good      0-5
# 4                             26.170594        Best      0-5

# %%
def get_y(pos):
  y = ast.literal_eval(pos)[1]
  return y

# %%
result_df["homePlayers_1_x"] = result_df["homePlayers_1_xyz"].apply(get_x)
result_df["homePlayers_1_y"] = result_df["homePlayers_1_xyz"].apply(get_y)

# %%
result_df.head()
# Out:
#    period  gameClock  homePlayers_1_number    homePlayers_1_xyz  \
# 0       1       0.00                    25  [-11.08, 1.55, 0.0]
# 1       1       0.04                    25  [-11.08, 1.57, 0.0]
# 2       1       0.08                    25  [-11.07, 1.59, 0.0]
# 3       1       0.12                    25  [-11.07, 1.61, 0.0]
# 4       1       0.16                    25  [-11.05, 1.63, 0.0]
#
#    homePlayers_1_ballDistance  homePlayers_1_speed   homePlayers_3_xyz  \
# 0                   10.857260                 0.00  [-2.71, 8.54, 0.0]
# 1                   10.348435                 0.00  [-2.71, 8.52, 0.0]
# 2                    9.815141                 0.53   [-2.71, 8.5, 0.0]
# 3                    9.347347                 0.60  [-2.72, 8.48, 0.0]
# 4                    8.831308                 0.64  [-2.72, 8.46, 0.0]
#
#    homePlayers_1_homePlayers_3_Distance     homePlayers_5_xyz  \
# 0                             10.904907   [-1.2, -13.96, 0.0]
# 1                             10.879311  [-1.22, -13.95, 0.0]
# 2                             10.846091  [-1.24, -13.93, 0.0]
# 3                             10.812927  [-1.27, -13.92, 0.0]
# 4                             10.772084   [-1.29, -13.9, 0.0]
#
#    homePlayers_1_homePlayers_5_Distance    awayPlayers_1_xyz  \
# 0                             18.389521  [11.04, -4.63, 0.0]
# 1                             18.387224  [11.05, -4.63, 0.0]
# 2                             18.371154  [11.05, -4.64, 0.0]
# 3                             18.363575  [11.05, -4.65, 0.0]
# 4                             18.342260  [11.04, -4.67, 0.0]
#
#    homePlayers_1_awayPlayers_1_Distance   awayPlayers_8_xyz  \
# 0                             22.967081  [14.89, 5.64, 0.0]
# 1                             22.982100  [14.88, 5.64, 0.0]
# 2                             22.980585  [14.86, 5.64, 0.0]
# 3                             22.988736  [14.83, 5.65, 0.0]
# 4                             22.970810  [14.81, 5.65, 0.0]
#
#    homePlayers_1_awayPlayers_8_Distance Performance fiveMins  homePlayers_1_x  \
# 0                             26.290093        Good      NaN           -11.08
# 1                             26.277110        Good      0-5           -11.08
# 2                             26.244378        Good      0-5           -11.07
# 3                             26.213195        Good      0-5           -11.07
# 4                             26.170594        Best      0-5           -11.05
#
#    homePlayers_1_y
# 0             1.55
# 1             1.57
# 2             1.59
# 3             1.61
# 4             1.63

# %%
result_df_best = result_df[result_df["Performance"]=="Best"]

# %%
sns.kdeplot(data=result_df_best, x='homePlayers_1_x', y='homePlayers_1_y', fill=True, cmap="Blues", thresh=0.05)
plt.xlabel("Length of field")
plt.ylabel("Width of field")
plt.title("Best performance regions for home player 1")
plt.show()

# %%
result_df_poor = result_df[result_df["Performance"]=="Poor"]

# %%
sns.kdeplot(data=result_df_poor, x='homePlayers_1_x', y='homePlayers_1_y', fill=True, cmap="Blues", thresh=0.05)
plt.xlabel("Length of field")
plt.ylabel("Width of field")
plt.title("Poor performance regions for home player 1")
plt.show()

# %%
result_df.to_csv("/content/drive/My Drive/MCI Women_s Files/HomePlayer1_MF_Analysis_Result.csv",index=False)
